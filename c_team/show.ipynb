# %%
from chaining import get_chain
from datasets import Dataset
from ragas.metrics import (
    faithfulness,
    context_recall,
    answer_relevancy,
    context_precision,
)
from chaining import get_chain, get_retriever
from verification_datas import datas
chain = get_chain()
from pprint import pprint
# Out:
# /var/folders/kz/rts6j3mj2nj3xm6c6kf4t1h80000gn/T/ipykernel_21350/226780843.py:3: DeprecationWarning: Importing faithfulness from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import faithfulness
#   from ragas.metrics import (
# /var/folders/kz/rts6j3mj2nj3xm6c6kf4t1h80000gn/T/ipykernel_21350/226780843.py:3: DeprecationWarning: Importing context_recall from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_recall
#   from ragas.metrics import (
# /var/folders/kz/rts6j3mj2nj3xm6c6kf4t1h80000gn/T/ipykernel_21350/226780843.py:3: DeprecationWarning: Importing answer_relevancy from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import answer_relevancy
#   from ragas.metrics import (
# /var/folders/kz/rts6j3mj2nj3xm6c6kf4t1h80000gn/T/ipykernel_21350/226780843.py:3: DeprecationWarning: Importing context_precision from 'ragas.metrics' is deprecated and will be removed in v1.0. Please use 'ragas.metrics.collections' instead. Example: from ragas.metrics.collections import context_precision
#   from ragas.metrics import (
# /Users/tera/Desktop/workspace/skn_21/project/project_03_1team_repo/.venv/lib/python3.13/site-packages/langchain_qdrant/qdrant.py:465: UserWarning: Api key is used with an insecure connection.
#   client = QdrantClient(

# %%
query="우리집에 어떤 사람이 대문을 부수고 들어왔어. 강도같아서 밀쳤는데 이 과정에서 그 사람이 다쳤으면 내가 책임이 있어?"

result = chain.invoke(query)
print(result)
# Out:
# 형사법 정보
#
# - 적용될 수 있는 형법 규정(정당방위/과잉방위)
#   - 형법 제21조(정당방위): 자기 또는 타인의 법익에 대한 현재의 부당한 침해를 방위하기 위한 상당한 행위는 처벌되지 않습니다.
#   - 형법 제21조 제2항·제3항(과잉방위): 방위행위가 정도를 초과한 경우 형을 감경 또는 면제할 수 있으며, 야간 등 불안스러운 상황에서 공포·흥분 등으로 인한 과잉방위는 처벌되지 않거나 감경될 수 있습니다.
#   - 요지: 침입자가 대문을 부수고 들어오는 것은 현재의 부당한 침해(주거에 대한 침해)에 해당할 수 있어, 그 침해를 막기 위한 상당한 범위 내의 밀침 등 방위행위는 형사책임이 발생하지 않을 수 있습니다. 다만 방위의 한도를 현저히 벗어나 상대방에게 상해를 입힌 경우에는 과잉방위 판단에 따라 감경·면제 또는 처벌 가능성이 문제될 수 있습니다.
#
# - 침입행위 관련 조문
#   - 형법 제319조 제1항(주거침입): 타인의 주거 등에 침입한 경우 처벌됩니다. 대문을 부수고 들어오는 행위는 주거침입 및 손괴 등의 범죄 성부 판단에 직접 관련됩니다.
#
# 참고자료(제공된 자료)
# - 제3조(특수강도강간 등)①「형법」제319조제1항(주거침입),
# - 제140조의2(부동산강제집행효용침해) 강제집행으로 명도 또는 인도된 부동산에 침입하거나 기타 방법으로 강제집행의 효용을 해한 자는 5년 이하의 징역 또는 700만원 이하의 벌금에 처한다.[본조신설 1995. 12. 29.]
# - 제184조(수리방해) 둑을 무너뜨리거나 수문을 파괴하거나 그 밖의 방법으로 수리(水利)를 방해한 자는 5년 이하의 징역 또는 700만원 이하의 벌금에 처한다.[전문개정 2020. 12. 8.] 제15장 교통방해의 죄
# - 제286조(미수범)의 죄
# - 「형법」제2편 제32장 강간과 추행의 죄 중 제141조(공용서류 등의 무효, 공용물의 파괴)의 죄
# - 「형법」제24장 살인의 죄 중 제250조 제1항(살인)
#
# 추가로 관련될 수 있는 형사법 조문
# - 형법 제21조(정당방위), 제21조 제2항·제3항(과잉방위)
# - 형법 제20조(정당행위)
# - 형법 제22조(긴급피난)
# - 형법 제319조 제1항(주거침입)
